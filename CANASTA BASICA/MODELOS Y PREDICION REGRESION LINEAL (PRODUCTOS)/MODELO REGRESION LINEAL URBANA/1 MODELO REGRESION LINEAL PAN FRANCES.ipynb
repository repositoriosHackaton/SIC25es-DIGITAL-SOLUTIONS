# %% [markdown]
# # __ETAPA 1: CARGAR Y EXPLORAR LOS DATOS__

# %%
import pandas as pd

# Cargar el archivo CSV
df = pd.read_csv(r"C:\Users\Angel Temporal\CANASTA BASICA PROYECTO\DATA SET\URBANA\canasta_basica_urbana_PREPROCESADO.csv")

# Ver las columnas del dataset
df.columns
# Out:
# Index(['AÑO', 'ARTICULO', 'GRAMOS POR PERSONAS', 'ENERO', 'FEBRERO', 'MARZO',
#        'ABRIL', 'MAYO', 'JUNIO', 'JULIO', 'AGOSTO', 'SEPTIEMBRE', 'OCTUBRE',
#        'NOVIEMBRE', 'DICIEMBRE'],
#       dtype='object')

# %%
import pandas as pd


# Cargar el archivo CSV
df = pd.read_csv(r"C:\Users\Angel Temporal\CANASTA BASICA PROYECTO\DATA SET\URBANA\canasta_basica_urbana_PREPROCESADO.csv")

# Establecer el número máximo de decimales a mostrar
pd.set_option('display.float_format', '{:,.4f}'.format)


# Mostrar las primeras 60 filas para verificar
df.head()
# Out:
#     AÑO      ARTICULO  GRAMOS POR PERSONAS  ENERO  FEBRERO  MARZO  ABRIL  \
# 0  2001   Pan Francés                   49 0.0700   0.0700 0.0700 0.0700
# 1  2001     Tortillas                  223 0.1100   0.1100 0.1100 0.1100
# 2  2001         Arroz                   55 0.0500   0.0500 0.0500 0.0500
# 3  2001   Carnes 1_ /                   60 0.2500   0.2500 0.2500 0.2500
# 4  2001  Grasas 2 _ /                   33 0.0500   0.0500 0.0500 0.0500
#
#     MAYO  JUNIO  JULIO  AGOSTO  SEPTIEMBRE  OCTUBRE  NOVIEMBRE  DICIEMBRE
# 0 0.0700 0.0600 0.0600  0.0700      0.0600   0.0600     0.0700     0.0700
# 1 0.1100 0.1100 0.1200  0.1200      0.1200   0.1200     0.1100     0.1100
# 2 0.0500 0.0500 0.0500  0.0500      0.0500   0.0400     0.0500     0.0500
# 3 0.2500 0.2600 0.2600  0.2600      0.2600   0.2600     0.2600     0.2600
# 4 0.0500 0.0500 0.0500  0.0500      0.0500   0.0500     0.0500     0.0500

# %% [markdown]
# # __ETAPA 2: FILTRAR LOS DATOS DEL PAN FRANCES__

# %%
# Filtrar solo el Pan Francés
df_pan = df[df["ARTICULO"] == "Pan Francés"].copy()


#df.drop(264, inplace=True)
df_pan = df_pan.drop(264, axis=0)

# Verificar el dataset filtrado

df_pan.head(25)
# Out:
#       AÑO     ARTICULO  GRAMOS POR PERSONAS  ENERO  FEBRERO  MARZO  ABRIL  \
# 0    2001  Pan Francés                   49 0.0700   0.0700 0.0700 0.0700
# 11   2002  Pan Francés                   49 0.0700   0.0600 0.0700 0.0700
# 22   2003  Pan Francés                   49 0.0700   0.0700 0.0700 0.0700
# 33   2004  Pan Francés                   49 0.0700   0.0700 0.0700 0.0700
# 44   2005  Pan Francés                   49 0.0800   0.0700 0.0800 0.0700
# 55   2006  Pan Francés                   49 0.0800   0.0700 0.0800 0.0800
# 66   2007  Pan Francés                   49 0.0700   0.0800 0.0800 0.0800
# 77   2008  Pan Francés                   49 0.0900   0.1000 0.1100 0.1100
# 88   2009  Pan Francés                   49 0.1100   0.1200 0.1200 0.1100
# 99   2010  Pan Francés                   49 0.1100   0.1100 0.1000 0.1100
# 110  2011  Pan Francés                   49 0.1000   0.1100 0.1100 0.1100
# 121  2012  Pan Francés                   49 0.1000   0.1000 0.1000 0.1000
# 132  2013  Pan Francés                   49 0.1100   0.1100 0.1100 0.1100
# 143  2014  Pan Francés                   49 0.1100   0.1100 0.1100 0.1100
# 154  2015  Pan Francés                   49 0.1200   0.1200 0.1200 0.1200
# 165  2016  Pan Francés                   49 0.1200   0.1400 0.1300 0.1300
# 176  2017  Pan Francés                   49 0.1100   0.1200 0.1100 0.1300
# 187  2018  Pan Francés                   49 0.1200   0.1200 0.1200 0.1200
# 198  2019  Pan Francés                   49 0.1200   0.1300 0.1200 0.1100
# 209  2020  Pan Francés                   49 0.1100   0.1100 0.1200 0.1200
# 220  2021  Pan Francés                   49 0.1200   0.1300 0.1300 0.1100
# 231  2022  Pan Francés                   49 0.1457   0.1524 0.1660 0.1637
# 242  2023  Pan Francés                   49 0.1624   0.1779 0.1752 0.1697
# 253  2024  Pan Francés                   49 0.1668   0.1667 0.1703 0.1665
#
#       MAYO  JUNIO  JULIO  AGOSTO  SEPTIEMBRE  OCTUBRE  NOVIEMBRE  DICIEMBRE
# 0   0.0700 0.0600 0.0600  0.0700      0.0600   0.0600     0.0700     0.0700
# 11  0.0700 0.0700 0.0700  0.0700      0.0700   0.0700     0.0700     0.0700
# 22  0.0700 0.0700 0.0700  0.0700      0.0700   0.0700     0.0700     0.0800
# 33  0.0700 0.0700 0.0700  0.0700      0.0700   0.0700     0.0800     0.0800
# 44  0.0700 0.0700 0.0700  0.0700      0.0700   0.0800     0.0800     0.0800
# 55  0.0700 0.0800 0.0800  0.0700      0.0800   0.0800     0.0800     0.0800
# 66  0.0800 0.0800 0.0800  0.0800      0.0800   0.0800     0.0900     0.0900
# 77  0.1100 0.1200 0.1200  0.1200      0.1200   0.1100     0.1100     0.1100
# 88  0.1100 0.1100 0.1100  0.1100      0.1100   0.1100     0.1200     0.1100
# 99  0.1100 0.1100 0.1100  0.1100      0.1100   0.1100     0.1100     0.1100
# 110 0.1100 0.1100 0.1100  0.1100      0.1100   0.1100     0.1100     0.1000
# 121 0.0900 0.0900 0.0900  0.1000      0.1000   0.1100     0.1100     0.1100
# 132 0.1100 0.1100 0.1100  0.1100      0.1100   0.1100     0.1100     0.1100
# 143 0.1100 0.1100 0.1100  0.1100      0.1100   0.1100     0.1200     0.1200
# 154 0.1200 0.1200 0.1200  0.1200      0.1300   0.1200     0.1200     0.1400
# 165 0.1300 0.1100 0.1300  0.1200      0.1300   0.1300     0.1300     0.1300
# 176 0.1200 0.1200 0.1200  0.1200      0.1200   0.1200     0.1300     0.1200
# 187 0.1200 0.1200 0.1200  0.1200      0.1200   0.1200     0.1300     0.1200
# 198 0.1200 0.1200 0.1200  0.1200      0.1100   0.1100     0.1200     0.1200
# 209 0.1300 0.1300 0.1300  0.1200      0.1200   0.1200     0.1200     0.1200
# 220 0.1200 0.1300 0.1300  0.1400      0.1400   0.1400     0.1500     0.1500
# 231 0.1580 0.1656 0.1813  0.1672      0.1806   0.1697     0.1683     0.1626
# 242 0.1671 0.1774 0.1727  0.1756      0.1762   0.1666     0.1727     0.1746
# 253 0.1734 0.1780 0.1703  0.1656      0.1626   0.1656     0.1679     0.1678

# %% [markdown]
# # __ETAPA 3: TRANFORMAR LOS DATOS EN UN FORMATO ANCHO A LARGO__

# %%
import pandas as pd

# Asegúrate de cargar el DataFrame 'df_pan' antes de ejecutar este código

# Transformar de formato ancho (varias columnas de meses) a largo (fecha única)
df_pan_melted = df_pan.melt(id_vars=["AÑO", "ARTICULO"], 
                            value_vars=["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO", 
                                        "JULIO", "AGOSTO", "SEPTIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"],
                            var_name="MES", value_name="PRECIO")

# Mapeo de nombres de meses a números
meses_dict = {
    "ENERO": 1, "FEBRERO": 2, "MARZO": 3, "ABRIL": 4, "MAYO": 5, "JUNIO": 6,
    "JULIO": 7, "AGOSTO": 8, "SEPTIEMBRE": 9, "OCTUBRE": 10, "NOVIEMBRE": 11, "DICIEMBRE": 12
}

# Convertir los nombres de los meses a números
df_pan_melted["MES"] = df_pan_melted["MES"].map(meses_dict)

# Crear la columna de fecha
df_pan_melted["FECHA"] = pd.to_datetime(df_pan_melted["AÑO"].astype(str) + "-" + df_pan_melted["MES"].astype(str) + "-01")

# Ordenar por fecha y eliminar columnas innecesarias
df_pan_melted = df_pan_melted.sort_values("FECHA")[["FECHA", "PRECIO"]]

# Reiniciar el índice
df_pan_melted.reset_index(drop=True, inplace=True)

df_pan_melted.index = df_pan_melted.index + 1


# Mostrar los primeros registros 
df_pan_melted.head()
# Out:
#        FECHA  PRECIO
# 1 2001-01-01  0.0700
# 2 2001-02-01  0.0700
# 3 2001-03-01  0.0700
# 4 2001-04-01  0.0700
# 5 2001-05-01  0.0700

# %%
#VERIFICACION CORRECTA DE LAS SERIES TEMPORALES
df_pan_melted
# Out:
#          FECHA  PRECIO
# 1   2001-01-01  0.0700
# 2   2001-02-01  0.0700
# 3   2001-03-01  0.0700
# 4   2001-04-01  0.0700
# 5   2001-05-01  0.0700
# ..         ...     ...
# 284 2024-08-01  0.1656
# 285 2024-09-01  0.1626
# 286 2024-10-01  0.1656
# 287 2024-11-01  0.1679
# 288 2024-12-01  0.1678
#
# [288 rows x 2 columns]

# %% [markdown]
# # __ETAPA 4: GRAFICAR LA EVOLUCION DEL PRECIO DEL PAN FRANCES__

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import numpy as np  # Para generar el rango de valores del eje Y

# Convertir la columna FECHA a datetime (si no lo está)
df_pan_melted["FECHA"] = pd.to_datetime(df_pan_melted["FECHA"])

# Graficar la serie temporal
plt.figure(figsize=(12,6))
plt.plot(df_pan_melted["FECHA"], df_pan_melted["PRECIO"], marker="o", linestyle="", color="b", label="Precio Pan Francés")

# Personalizar el eje X para mostrar un año por año
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

# Definir los valores del eje Y manualmente
y_ticks = np.arange(0.0600, 0.1901, 0.0050)  # Desde 0.0600 hasta 0.1900, con incrementos de 0.0050
plt.yticks(y_ticks)

# Ajustar los límites del eje Y
#plt.ylim(0.0600, 0.1900)  # Establecer el rango del eje Y

# Formatear las etiquetas del eje Y para mostrar 4 decimales
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.4f'))

plt.xlabel("Fecha")
plt.ylabel("Precio ($)")
plt.title("Evolución del Precio del Pan Francés")
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import numpy as np  # Para generar el rango de valores del eje Y

# Convertir la columna FECHA a datetime (si no lo está)
df_pan_melted["FECHA"] = pd.to_datetime(df_pan_melted["FECHA"])

# Graficar la serie temporal
plt.figure(figsize=(12,6))
plt.plot(df_pan_melted["FECHA"], df_pan_melted["PRECIO"], marker="o", linestyle="-", color="b", label="Precio Pan Francés")

# Personalizar el eje X para mostrar un año por año
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

# Definir los valores del eje Y manualmente
y_ticks = np.arange(0.0600, 0.1901, 0.0050)  # Desde 0.0600 hasta 0.1900, con incrementos de 0.0050
plt.yticks(y_ticks)

# Ajustar los límites del eje Y
#plt.ylim(0.0600, 0.1900)  # Establecer el rango del eje Y

# Formatear las etiquetas del eje Y para mostrar 4 decimales
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.4f'))

plt.xlabel("Fecha")
plt.ylabel("Precio ($)")
plt.title("Evolución del Precio del Pan Francés")
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# # __ETAPA 5: DIVISION DEL CONJUNTO DE DATOS__

# %%
df_pan_melted["FECHA_ORD"] = df_pan_melted["FECHA"].map(lambda x: x.toordinal())

# %%
from sklearn.model_selection import train_test_split

# Variables independientes (X) y dependientes (y)
X = df_pan_melted[["FECHA_ORD"]]  # Matriz de características
y = df_pan_melted["PRECIO"]       # Variable objetivo

# División en entrenamiento y prueba (80% entrenamiento, 20% prueba)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# # __ETAPA 6: ENTRENAMIENTO DEL MODELO DE REGRESION LINEAL__

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

modelo.fit(X_train, y_train)

print(f"Pendiente (m): {modelo.coef_[0]}")
print(f"Intercepto (b): {modelo.intercept_}")

y_pred = modelo.predict(X_test)
# Out:
# Pendiente (m): 9.435425651058903e-06
# Intercepto (b): -6.826145575134993

# %%
# Convertir la columna FECHA a datetime (si no lo está)
df_pan_melted["FECHA"] = pd.to_datetime(df_pan_melted["FECHA"])

# Convertir la FECHA a formato ordinal para regresión
df_pan_melted["FECHA_ORD"] = df_pan_melted["FECHA"].map(lambda x: x.toordinal())

# Definir variables para regresión
X = df_pan_melted[["FECHA_ORD"]].values  # Característica (fecha en ordinal)
y = df_pan_melted["PRECIO"].values       # Variable objetivo (precio del pan)

# Entrenar modelo de regresión lineal
modelo = LinearRegression()
modelo.fit(X, y)

# Generar predicciones sobre los datos históricos
y_pred = modelo.predict(X)

# Predecir precios futuros (2025-2030)
fechas_futuras = pd.date_range(start="2025-01-01", end="2030-12-01", freq="ME")
fechas_futuras_ordinal = np.array([fecha.toordinal() for fecha in fechas_futuras]).reshape(-1, 1)
precios_predichos = modelo.predict(fechas_futuras_ordinal)

# Graficar datos reales y regresión lineal
plt.figure(figsize=(12,6))

# Datos históricos
plt.scatter(df_pan_melted["FECHA"], df_pan_melted["PRECIO"], color="blue", label="Precio Real", alpha=0.7)

# Línea de regresión en datos históricos
plt.plot(df_pan_melted["FECHA"], y_pred, color="red", linewidth=2, label="Regresión Lineal")

# Predicciones futuras
plt.scatter(fechas_futuras, precios_predichos, color="green", label="Predicciones 2025-2030", alpha=0.7)

# Personalizar eje X
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())  # Mostrar cada año
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))  # Formato Año

# Definir el rango del eje Y
y_ticks = np.arange(0.0600, 0.1901, 0.0050)
plt.yticks(y_ticks)

# Personalizar la gráfica
plt.xlabel("Fecha")
plt.ylabel("Precio ($)")
plt.title("Evolución y Predicción del Precio del Pan Francés (2025-2030)")
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # __ETAPA 7: EVALUACION DEL MODELO__

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calcular métricas de evaluación
mse = mean_squared_error(y, y_pred)  # Error cuadrático medio
rmse = np.sqrt(mse)  # Raíz del error cuadrático medio
mae = mean_absolute_error(y, y_pred)  # Error absoluto medio
r2 = r2_score(y, y_pred)  # Coeficiente de determinación

# Imprimir resultados
print(f" Error Cuadrático Medio (MSE): {mse:.6f}")
print(f" Raíz del Error Cuadrático Medio (RMSE): {rmse:.6f}")
print(f" Error Absoluto Medio (MAE): {mae:.6f}")
print(f" Coeficiente de Determinación (R²): {r2:.6f}")

precision_percentage = r2 * 100
print(f"Porcentaje de precisión IA: ", precision_percentage)
# Out:
#  Error Cuadrático Medio (MSE): 0.000148
#  Raíz del Error Cuadrático Medio (RMSE): 0.012160
#  Error Absoluto Medio (MAE): 0.009589
#  Coeficiente de Determinación (R²): 0.841078
# Porcentaje de precisión IA:  84.10781603484185

# %% [markdown]
# ## __Análisis de la Evaluación del Modelo__
#
# * Error Cuadrático Medio (MSE): 0.000148 = Muy pequeño, lo cual es bueno.
#
# * Raíz del Error Cuadrático Medio (RMSE): 0.012160 = En promedio, el modelo tiene un error de aproximadamente 1.2 centavos en la predicción del precio del pan.
#
# * Error Absoluto Medio (MAE): 0.009589 = Indica que, en promedio, el modelo se equivoca por 0.96 centavos por predicción.
#
# * Coeficiente de Determinación (R²): 0.841078 = Indica que el 84.1% de la variabilidad en el precio del pan se explica por la fecha.

# %% [markdown]
# # __ETAPA 8: VISUALIZACION DE RESULTADOS__

# %% [markdown]
# ## __Gráfico de Datos Reales y Regresión Lineal__
#
# Este gráfico muestra los datos reales en azul, la línea de regresión en rojo y las predicciones futuras en verde

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

# Crear la figura
plt.figure(figsize=(12,6))

#  Datos reales
plt.scatter(df_pan_melted["FECHA"], df_pan_melted["PRECIO"], color="blue", label="Precio Real", alpha=0.7)

# Línea de regresión sobre datos históricos
plt.plot(df_pan_melted["FECHA"], y_pred, color="red", linewidth=2, label="Regresión Lineal")

# Predicciones futuras
plt.scatter(fechas_futuras, precios_predichos, color="green", label="Predicciones 2025-2030", alpha=0.7)

# Personalizar eje X con fechas legibles
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())  # Mostrar cada año
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))  # Formato Año

# Definir el rango del eje Y
y_ticks = np.arange(0.0600, 0.1901, 0.0050)
plt.yticks(y_ticks)

# Personalizar la gráfica
plt.xlabel("Fecha")
plt.ylabel("Precio ($)")
plt.title(" Evolución y Predicción del Precio del Pan Francés (2025-2030)")
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## __Evolución y Predicción del Precio del Pan Francés (2025-2030)__
#
#     Se observa una tendencia creciente en el precio del pan a lo largo de los años.
#
#     La regresión lineal (línea roja) ajusta razonablemente bien los datos históricos, aunque se nota que algunos valores reales presentan una dispersión considerable.
#
#     Las predicciones para el período 2025-2030 (puntos verdes) siguen la tendencia establecida, pero es importante recordar que la regresión lineal asume una relación lineal, lo cual puede no capturar completamente la variabilidad real del mercado.

# %% [markdown]
# ## __Gráfico de Residuos__
#
# Este gráfico nos ayuda a ver si el modelo tiene patrones en sus errores

# %%
import seaborn as sns

# Cálculo de los residuos
residuos = y - y_pred  

# Crear gráfico de dispersión de residuos
plt.figure(figsize=(12,5))
plt.scatter(df_pan_melted["FECHA"], residuos, color="purple", alpha=0.6)
plt.axhline(y=0, color='black', linestyle='--', linewidth=1.5)  # Línea de referencia

# Personalizar el gráfico
plt.xlabel("Fecha")
plt.ylabel("Error de Predicción (Residuo)")
plt.title(" Análisis de Residuos")
plt.grid()
plt.show()

# %% [markdown]
# ## __Análisis de Residuos__
#
#     Los residuos (errores entre valores reales y predichos) están distribuidos en torno a la línea horizontal de referencia (0).
#
#     Se observa un patrón no aleatorio en algunas secciones, lo cual sugiere que la regresión lineal no capta perfectamente todas las variaciones del precio del pan.
#
#     La dispersión de los residuos parece aumentar en años recientes, lo que indica que el modelo puede tener más dificultades para ajustarse a cambios recientes en la dinámica del precio.

# %% [markdown]
# ## __Histograma de Errores__
#
# Este gráfico muestra cómo están distribuidos los errores del modelo.

# %%
# Crear histograma de errores
plt.figure(figsize=(10,5))
sns.histplot(residuos, bins=20, kde=True, color="orange")

# Personalizar
plt.xlabel("Error de Predicción (Residuo)")
plt.ylabel("Frecuencia")
plt.title("Distribución de Errores del Modelo")
plt.grid()
plt.show()

# %% [markdown]
# ## __Distribución de Errores del Modelo__
#
#     La distribución de los errores parece tener una forma aproximadamente normal, lo cual es un buen indicador de que el modelo no tiene sesgos evidentes.
#
#     Sin embargo, se observan algunos valores extremos en ambos lados, lo que indica que en ciertos casos el modelo comete errores más grandes.

# %% [markdown]
# # __Conclusión del Proyecto: Predicción del Precio del Pan Francés en El Salvador__
#
# ## Este proyecto tuvo como objetivo analizar la evolución del precio del pan francés en El Salvador y predecir su comportamiento futuro utilizando un modelo de regresión lineal. Se recopilaron datos históricos de precios desde 2001 hasta 2024, los cuales fueron procesados y visualizados para identificar tendencias y patrones.
