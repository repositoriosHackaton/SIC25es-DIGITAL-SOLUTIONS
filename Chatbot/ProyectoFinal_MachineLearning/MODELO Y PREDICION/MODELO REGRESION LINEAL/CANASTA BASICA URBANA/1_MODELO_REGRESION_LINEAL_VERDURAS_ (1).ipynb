# %% [markdown]
# # __ETAPA 1: CARGAR Y EXPLORAR LOS DATOS__

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-909b30eb-c113-4792-ac4b-5d743587e6d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-909b30eb-c113-4792-ac4b-5d743587e6d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Cargar el archivo CSV
df = pd.read_csv(r"/content/drive/MyDrive/CANASTA BASICA PROYECTO/DATA SET/URBANA/canasta_basica_urbana_PREPROCESADO.csv")

# Ver las columnas del dataset
df.columns
# Out:
# Index(['AÑO', 'ARTICULO', 'GRAMOS POR PERSONAS', 'ENERO', 'FEBRERO', 'MARZO',
#        'ABRIL', 'MAYO', 'JUNIO', 'JULIO', 'AGOSTO', 'SEPTIEMBRE', 'OCTUBRE',
#        'NOVIEMBRE', 'DICIEMBRE'],
#       dtype='object')

# %%
import pandas as pd


# Cargar el archivo CSV
df = pd.read_csv(r"/content/drive/MyDrive/CANASTA BASICA PROYECTO/DATA SET/URBANA/canasta_basica_urbana_PREPROCESADO.csv")

# Establecer el número máximo de decimales a mostrar
pd.set_option('display.float_format', '{:,.4f}'.format)


# Mostrar las primeras 60 filas para verificar
df.head(11)
# Out:
#      AÑO        ARTICULO  GRAMOS POR PERSONAS  ENERO  FEBRERO  MARZO  ABRIL  \
# 0   2001     Pan Francés                   49 0.0700   0.0700 0.0700 0.0700
# 1   2001       Tortillas                  223 0.1100   0.1100 0.1100 0.1100
# 2   2001           Arroz                   55 0.0500   0.0500 0.0500 0.0500
# 3   2001     Carnes 1_ /                   60 0.2500   0.2500 0.2500 0.2500
# 4   2001    Grasas 2 _ /                   33 0.0500   0.0500 0.0500 0.0500
# 5   2001          Huevos                   28 0.0600   0.0600 0.0600 0.0600
# 6   2001  Leche Fluida *                  106 0.0800   0.0800 0.0800 0.0800
# 7   2001     Frutas 3_ /                  157 0.0600   0.0600 0.0600 0.0600
# 8   2001        Frijoles                   79 0.0700   0.0700 0.0700 0.0700
# 9   2001   Verduras 4_ /                  127 0.1100   0.1100 0.1100 0.1100
# 10  2001          Azúcar                   69 0.0400   0.0400 0.0400 0.0400
#
# ...

# %%
df.tail(11)
# Out:
#       AÑO        ARTICULO  GRAMOS POR PERSONAS  ENERO  FEBRERO  MARZO  ABRIL  \
# 264  2025     Pan Francés                   49 0.1684   0.0000 0.0000 0.0000
# 265  2025       Tortillas                  223 0.2408   0.0000 0.0000 0.0000
# 266  2025           Arroz                   55 0.0867   0.0000 0.0000 0.0000
# 267  2025     Carnes 1_ /                   60 0.5037   0.0000 0.0000 0.0000
# 268  2025    Grasas 2 _ /                   33 0.1137   0.0000 0.0000 0.0000
# 269  2025          Huevos                   28 0.1056   0.0000 0.0000 0.0000
# 270  2025  Leche Fluida *                  106 0.1174   0.0000 0.0000 0.0000
# 271  2025     Frutas 3_ /                  157 0.1694   0.0000 0.0000 0.0000
# 272  2025        Frijoles                   79 0.2138   0.0000 0.0000 0.0000
# 273  2025   Verduras 4_ /                  127 0.2049   0.0000 0.0000 0.0000
# 274  2025          Azúcar                   69 0.0794   0.0000 0.0000 0.0000
#
# ...

# %% [markdown]
# # __ETAPA 2: FILTRAR LOS DATOS DE LAS VERDURAS__

# %%
df_verduras_4 = df[df["ARTICULO"] == "Verduras 4_ /"].copy()

# Eliminar la fila con índice 273 si existe
if 273 in df_verduras_4.index:
    df_verduras_4 = df_verduras_4.drop(273, axis=0)

# Verificar el dataset filtrado
df_verduras_4.head(25)
# Out:
#       AÑO       ARTICULO  GRAMOS POR PERSONAS  ENERO  FEBRERO  MARZO  ABRIL  \
# 9    2001  Verduras 4_ /                  127 0.1100   0.1100 0.1100 0.1100
# 20   2002  Verduras 4_ /                  127 0.0900   0.0900 0.0900 0.1000
# 31   2003  Verduras 4_ /                  127 0.1100   0.1100 0.1000 0.1000
# 42   2004  Verduras 4_ /                  127 0.1100   0.1000 0.0900 0.1000
# 53   2005  Verduras 4_ /                  127 0.1100   0.1100 0.1100 0.1000
# 64   2006  Verduras 4_ /                  127 0.1000   0.0900 0.0900 0.1000
# 75   2007  Verduras 4_ /                  127 0.1600   0.1400 0.1400 0.1300
# 86   2008  Verduras 4_ /                  127 0.1200   0.1000 0.1000 0.1000
# 97   2009  Verduras 4_ /                  127 0.1300   0.1100 0.1000 0.1000
# 108  2010  Verduras 4_ /                  127 0.1400   0.1500 0.1700 0.1700
# 119  2011  Verduras 4_ /                  127 0.1400   0.1200 0.1100 0.1200
# ...

# %% [markdown]
# # __ETAPA 3: TRANFORMAR LOS DATOS EN UN FORMATO ANCHO A LARGO__

# %%
import pandas as pd

# Asegúrate de cargar el DataFrame 'df_verduras_4' antes de ejecutar este código

# Transformar de formato ancho (varias columnas de meses) a largo (fecha única)
df_verduras_4_melted = df_verduras_4.melt(id_vars=["AÑO", "ARTICULO"],
                            value_vars=["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
                                        "JULIO", "AGOSTO", "SEPTIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"],
                            var_name="MES", value_name="PRECIO")

# Mapeo de nombres de meses a números
meses_dict = {
    "ENERO": 1, "FEBRERO": 2, "MARZO": 3, "ABRIL": 4, "MAYO": 5, "JUNIO": 6,
    "JULIO": 7, "AGOSTO": 8, "SEPTIEMBRE": 9, "OCTUBRE": 10, "NOVIEMBRE": 11, "DICIEMBRE": 12
}

# Convertir los nombres de los meses a números
df_verduras_4_melted["MES"] = df_verduras_4_melted["MES"].map(meses_dict)

# Crear la columna de fecha
df_verduras_4_melted["FECHA"] = pd.to_datetime(df_verduras_4_melted["AÑO"].astype(str) + "-" + df_verduras_4_melted["MES"].astype(str) + "-01")

# Ordenar por fecha y eliminar columnas innecesarias
df_verduras_4_melted = df_verduras_4_melted.sort_values("FECHA")[["FECHA", "PRECIO"]]

# Reiniciar el índice
df_verduras_4_melted.reset_index(drop=True, inplace=True)

df_verduras_4_melted.index = df_verduras_4_melted.index + 1


# Mostrar los primeros registros
df_verduras_4_melted.head()
# Out:
#        FECHA  PRECIO
# 1 2001-01-01  0.1100
# 2 2001-02-01  0.1100
# 3 2001-03-01  0.1100
# 4 2001-04-01  0.1100
# 5 2001-05-01  0.1100

# %%
#VERIFICACION CORRECTA DE LAS SERIES TEMPORALES
df_verduras_4_melted
# Out:
#          FECHA  PRECIO
# 1   2001-01-01  0.1100
# 2   2001-02-01  0.1100
# 3   2001-03-01  0.1100
# 4   2001-04-01  0.1100
# 5   2001-05-01  0.1100
# ..         ...     ...
# 284 2024-08-01  0.2992
# 285 2024-09-01  0.2356
# 286 2024-10-01  0.2161
# 287 2024-11-01  0.2065
# 288 2024-12-01  0.2139
#
# [288 rows x 2 columns]

# %% [markdown]
# # __ETAPA 4: GRAFICAR LA EVOLUCION DEL PRECIO DE LAS VERDURAS__

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import numpy as np

# Convertir la columna FECHA a datetime (si no lo está)
df_verduras_4_melted["FECHA"] = pd.to_datetime(df_verduras_4_melted["FECHA"])

# Graficar la serie temporal como un área sombreada
plt.figure(figsize=(12,6))
plt.fill_between(df_verduras_4_melted["FECHA"], df_verduras_4_melted["PRECIO"], color="lightblue", alpha=0.6, label="Precio verduras")
plt.plot(df_verduras_4_melted["FECHA"], df_verduras_4_melted["PRECIO"], marker="o", linestyle="-", color="dodgerblue", label="Precio verduras", markersize=5)

# Personalizar el eje X para mostrar un año por año
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

# Definir los valores del eje Y manualmente
y_ticks = np.arange(0.0600, 0.1901, 0.0050)  # Desde 0.0600 hasta 0.1900, con incrementos de 0.0050
plt.yticks(y_ticks)

# Ajustar los límites del eje Y
plt.ylim(0.0600, 0.1900)  # Establecer el rango del eje Y

# Formatear las etiquetas del eje Y para mostrar 4 decimales
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.4f'))

# Mejorar la visibilidad de la gráfica
plt.xlabel("Fecha")
plt.ylabel("Precio ($)")
plt.title("Evolución del Precio de Verduras")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Analisis breve:La gráfica de líneas con área sombreada resalta la evolución del precio de las verduras, haciendo visible no solo la tendencia general sino también la fluctuación en los precios.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import numpy as np  # Para generar el rango de valores del eje Y

# Convertir la columna FECHA a datetime (si no lo está)
df_verduras_4_melted["FECHA"] = pd.to_datetime(df_verduras_4_melted["FECHA"])

# Graficar la serie temporal con color verde claro
plt.figure(figsize=(12,6))
plt.plot(df_verduras_4_melted["FECHA"], df_verduras_4_melted["PRECIO"], marker="o", linestyle="-", color="lightgreen", label="Precio de verduras")

# Personalizar el eje X para mostrar un año por año
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

# Definir los valores del eje Y manualmente
y_ticks = np.arange(0.0600, 0.1901, 0.0050)  # Desde 0.0600 hasta 0.1900, con incrementos de 0.0050
plt.yticks(y_ticks)

# Ajustar los límites del eje Y
# plt.ylim(0.0600, 0.1900)  # Establecer el rango del eje Y

# Formatear las etiquetas del eje Y para mostrar 4 decimales
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.4f'))

# Mejorar la visibilidad de la gráfica
plt.xlabel("Fecha")
plt.ylabel("Precio ($)")
plt.title("Evolución del Precio de Verduras")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Analisis breve:
# La gráfica presenta la evolución del precio de las verduras a lo largo del tiempo, la tendencia general muestra ciertos picos y caídas en los precios, lo que refleja la variabilidad de los precios de las verduras a lo largo de los años.

# %% [markdown]
# ___

# %% [markdown]
# # __ETAPA 5: DIVISION DEL CONJUNTO DE DATOS__

# %%
df_verduras_4_melted["FECHA_ORD"] = df_verduras_4_melted["FECHA"].map(lambda x: x.toordinal())

# %%
from sklearn.model_selection import train_test_split

# Variables independientes (X) y dependientes (y)
X = df_verduras_4_melted[["FECHA_ORD"]]  # Matriz de características
y = df_verduras_4_melted["PRECIO"]       # Variable objetivo

# División en entrenamiento y prueba (80% entrenamiento, 20% prueba)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# # __ETAPA 6: ENTRENAMIENTO DEL MODELO DE REGRESION LINEAL__

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

modelo.fit(X_train, y_train)

print(f"Pendiente (m): {modelo.coef_[0]}")
print(f"Intercepto (b): {modelo.intercept_}")

y_pred = modelo.predict(X_test)
# Out:
# Pendiente (m): 1.2791498988461516e-05
# Intercepto (b): -9.24918537505891

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import numpy as np
from sklearn.linear_model import LinearRegression

# Convertir la columna FECHA a datetime (si no lo está)
df_verduras_4_melted["FECHA"] = pd.to_datetime(df_verduras_4_melted["FECHA"])

# Convertir la FECHA a formato ordinal para regresión
df_verduras_4_melted["FECHA_ORD"] = df_verduras_4_melted["FECHA"].map(lambda x: x.toordinal())

# Definir variables para regresión
X = df_verduras_4_melted[["FECHA_ORD"]].values  # Característica (fecha en ordinal)
y = df_verduras_4_melted["PRECIO"].values       # Variable objetivo (precio del pan)

# Entrenar modelo de regresión lineal
modelo = LinearRegression()
modelo.fit(X, y)

# Generar predicciones sobre los datos históricos
y_pred = modelo.predict(X)

# Predecir precios futuros (2025-2030)
fechas_futuras = pd.date_range(start="2025-01-01", end="2030-12-01", freq="ME")
fechas_futuras_ordinal = np.array([fecha.toordinal() for fecha in fechas_futuras]).reshape(-1, 1)
precios_predichos = modelo.predict(fechas_futuras_ordinal)

# Graficar datos reales y regresión lineal
plt.figure(figsize=(12,6))

# Datos históricos
plt.scatter(df_verduras_4_melted["FECHA"], df_verduras_4_melted["PRECIO"], color="lightcoral", label="Precio Real", alpha=0.7)

# Línea de regresión en datos históricos
plt.plot(df_verduras_4_melted["FECHA"], y_pred, color="orange", linewidth=2, label="Regresión Lineal")

# Predicciones futuras
plt.scatter(fechas_futuras, precios_predichos, color="lightgreen", label="Predicciones 2025-2030", alpha=0.7)

# Personalizar eje X
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())  # Mostrar cada año
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))  # Formato Año

# Definir el rango del eje Y
y_ticks = np.arange(0.0600, 0.1901, 0.0050)
plt.yticks(y_ticks)

# Personalizar la gráfica
plt.xlabel("Fecha")
plt.ylabel("Precio ($)")
plt.title("Evolución y Predicción del Precio de las Verduras (2025-2030)")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # __ETAPA 7: EVALUACION DEL MODELO__

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calcular métricas de evaluación
mse = mean_squared_error(y, y_pred)  # Error cuadrático medio
rmse = np.sqrt(mse)  # Raíz del error cuadrático medio
mae = mean_absolute_error(y, y_pred)  # Error absoluto medio
r2 = r2_score(y, y_pred)  # Coeficiente de determinación

# Imprimir resultados
print(f" Error Cuadrático Medio (MSE): {mse:.6f}")
print(f" Raíz del Error Cuadrático Medio (RMSE): {rmse:.6f}")
print(f" Error Absoluto Medio (MAE): {mae:.6f}")
print(f" Coeficiente de Determinación (R²): {r2:.6f}")
# Out:
#  Error Cuadrático Medio (MSE): 0.000452
#  Raíz del Error Cuadrático Medio (RMSE): 0.021253
#  Error Absoluto Medio (MAE): 0.016027
#  Coeficiente de Determinación (R²): 0.769639

# %% [markdown]
# ## __Análisis de la Evaluación del Modelo__
#
# Error Cuadrático Medio (MSE): 0.000452 = Muy pequeño, lo que indica que el modelo tiene una baja cantidad de error cuadrático, lo cual es positivo.
#
# Raíz del Error Cuadrático Medio (RMSE): 0.021253 = En promedio, el modelo tiene un error de aproximadamente 2.1 centavos en la predicción del precio de las verduras.
#
# Error Absoluto Medio (MAE): 0.016027 = Indica que, en promedio, el modelo se equivoca por 1.6 centavos por predicción.
#
# Coeficiente de Determinación (R²): 0.841078 = Indica que el 84.1% de la variabilidad en el precio de las verduras se explica por la fecha, lo que sugiere un buen ajuste del modelo.

# %% [markdown]
# # __ETAPA 8: VISUALIZACION DE RESULTADOS__

# %% [markdown]
# ## __Gráfico de Datos Reales y Regresión Lineal__
#
# Este gráfico muestra los datos reales en azul, la línea de regresión en rojo y las predicciones futuras en verde

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

# Crear la figura
plt.figure(figsize=(12,6))

#  Datos reales
plt.scatter(df_verduras_4_melted["FECHA"], df_verduras_4_melted["PRECIO"], color="blue", label="Precio Real", alpha=0.7)

# Línea de regresión sobre datos históricos
plt.plot(df_verduras_4_melted["FECHA"], y_pred, color="red", linewidth=2, label="Regresión Lineal")

# Predicciones futuras
plt.scatter(fechas_futuras, precios_predichos, color="green", label="Predicciones 2025-2030", alpha=0.7)

# Personalizar eje X con fechas legibles
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())  # Mostrar cada año
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))  # Formato Año

# Definir el rango del eje Y
y_ticks = np.arange(0.0600, 0.1901, 0.0050)
plt.yticks(y_ticks)

# Personalizar la gráfica
plt.xlabel("Fecha")
plt.ylabel("Precio ($)")
plt.title(" Evolución y Predicción del Precio de las verduras (2025-2030)")
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## __Evolución y Predicción del Precio de las verduras (2025-2030)__
#
#     Se observa una tendencia creciente en el precio de las verduras a lo largo de los años.
#
#     La regresión lineal (línea roja) ajusta razonablemente bien los datos históricos, aunque se nota que algunos valores reales presentan una dispersión considerable.
#
#     Las predicciones para el período 2025-2030 (puntos verdes) siguen la tendencia establecida, pero es importante recordar que la regresión lineal asume una relación lineal, lo cual puede no capturar completamente la variabilidad real del mercado.

# %% [markdown]
# ## __Gráfico de Residuos__
#
# Este gráfico nos ayuda a ver si el modelo tiene patrones en sus errores

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cálculo de los residuos
residuos = y - y_pred

# Crear gráfico de dispersión de residuos
plt.figure(figsize=(12,5))
plt.scatter(df_verduras_4_melted["FECHA"], residuos, color="mediumorchid", alpha=0.6)
plt.axhline(y=0, color='black', linestyle='--', linewidth=1.5)  # Línea de referencia

# Personalizar el gráfico
plt.xlabel("Fecha")
plt.ylabel("Error de Predicción (Residuo)")
plt.title("Análisis de Residuos")
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## __Análisis de Residuos__
#
#     Los residuos (errores entre valores reales y predichos) están distribuidos en torno a la línea horizontal de referencia (0).
#
#     Se observa un patrón no aleatorio en algunas secciones, lo cual sugiere que la regresión lineal no capta perfectamente todas las variaciones del precio de verduras.
#
#     La dispersión de los residuos parece aumentar en años recientes, lo que indica que el modelo puede tener más dificultades para ajustarse a cambios recientes en la dinámica del precio.

# %% [markdown]
# ## __Histograma de Errores__
#
# Este gráfico muestra cómo están distribuidos los errores del modelo.

# %%
# Crear histograma de errores
plt.figure(figsize=(10,5))
sns.histplot(residuos, bins=20, kde=True, color="skyblue")

# Personalizar
plt.xlabel("Error de Predicción (Residuo)")
plt.ylabel("Frecuencia")
plt.title("Distribución de Errores del Modelo")
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## __Distribución de Errores del Modelo__
#
#     La distribución de los errores parece tener una forma aproximadamente normal, lo cual es un buen indicador de que el modelo no tiene sesgos evidentes.
#
#     Sin embargo, se observan algunos valores extremos en ambos lados, lo que indica que en ciertos casos el modelo comete errores más grandes.

# %% [markdown]
# # __Conclusión del Proyecto: Predicción del Precio de las verduras en El Salvador__
#
# ## Este proyecto tuvo como objetivo analizar la evolución del precio de las verduras en El Salvador y predecir su comportamiento futuro utilizando un modelo de regresión lineal. Se recopilaron datos históricos de precios desde 2001 hasta 2024, los cuales fueron procesados y visualizados para identificar tendencias y patrones.
